# %%
from binance.um_futures import UMFutures
import ta
import pandas as pd
from time import sleep

# %%
api_key = 'oEgiaX0YO5TMr3UYzeLUoBZA0yS33IuSODNSDMI8GxTRnYtMapEYYTAs1uEWNLfT'
api_secret = 'Qj9xNPWFiGTIlHdEcbBFpFnTHCtDa5WN4dmCGZ7xeZLMjvVTVhy71Pf4ZeCMz9A5'

# %%
client = UMFutures(key=api_key, secret=api_secret)

# %%
def get_tickers_usdt():
    tickers = []
    resp = client.ticker_price()
    for elem in resp:
        if 'USDT' in elem['symbol']:
            tickers.append(elem['symbol'])
    return tickers
get_tickers_usdt()
# Out:
# ['ZETAUSDT',
#  'FLOWUSDT',
#  'WUSDT',
#  'TUSDT',
#  'ETHUSDT',
#  'YFIUSDT',
#  'WAXPUSDT',
#  'SNTUSDT',
#  'VETUSDT',
#  'BOMEUSDT',
#  'SLPUSDT',
#  'XAIUSDT',
#  'MKRUSDT',
#  'TIAUSDT',
#  'CHRUSDT',
#  'RDNTUSDT',
#  'APTUSDT',
#  'ARUSDT',
#  'CFXUSDT',
#  'LITUSDT',
#  'IMXUSDT',
#  'HFTUSDT',
#  'STPTUSDT',
#  'GLMRUSDT',
#  'UMAUSDT',
#  'CTSIUSDT',
#  'MYROUSDT',
#  'YGGUSDT',
#  'ARKMUSDT',
#  'LRCUSDT',
#  'NTRNUSDT',
#  'DEFIUSDT',
#  'BTCUSDT_241227',
#  'CELOUSDT',
#  'ENAUSDT',
#  'USDCUSDT',
#  '1000XECUSDT',
#  'IOUSDT',
#  'OMUSDT',
#  'JOEUSDT',
#  'BANDUSDT',
#  'MTLUSDT',
#  'SUSHIUSDT',
#  'SEIUSDT',
#  'ONGUSDT',
#  'JUPUSDT',
#  'GTCUSDT',
#  'TAOUSDT',
#  'BTCDOMUSDT',
#  'ACEUSDT',
#  'BBUSDT',
#  'ROSEUSDT',
#  'OGNUSDT',
#  'WIFUSDT',
#  'BAKEUSDT',
#  'ICPUSDT',
#  'IOTXUSDT',
#  'ACHUSDT',
#  'MANTAUSDT',
#  'ETHUSDT_241227',
#  'XVGUSDT',
#  'QNTUSDT',
#  'ENJUSDT',
#  'GMTUSDT',
#  'MANAUSDT',
#  'ORBSUSDT',
#  'STMXUSDT',
#  'CHZUSDT',
#  'OXTUSDT',
#  'QTUMUSDT',
#  'CVXUSDT',
#  'MOVRUSDT',
#  'TONUSDT',
#  'OMGUSDT',
#  'DYMUSDT',
#  'PENDLEUSDT',
#  'KSMUSDT',
#  'EDUUSDT',
#  'WAVESUSDT',
#  'CAKEUSDT',
#  'ICXUSDT',
#  'ETCUSDT',
#  'RIFUSDT',
#  'PYTHUSDT',
#  'XRPUSDT',
#  'NFPUSDT',
#  'FRONTUSDT',
#  'ARPAUSDT',
#  'MEMEUSDT',
#  'PHBUSDT',
#  'AEVOUSDT',
#  'AXLUSDT',
#  'INJUSDT',
#  'GMXUSDT',
#  'ATAUSDT',
#  'ETHUSDT_240927',
#  'LDOUSDT',
#  'IOSTUSDT',
#  'AVAXUSDT',
#  'IDEXUSDT',
#  '1000SATSUSDT',
#  'METISUSDT',
#  'BLURUSDT',
#  'TLMUSDT',
#  'UNIUSDT',
#  'TRUUSDT',
#  'DOTUSDT',
#  'PEOPLEUSDT',
#  '1000BONKUSDT',
#  'COMPUSDT',
#  'AAVEUSDT',
#  'TRXUSDT',
#  'SUPERUSDT',
#  '1INCHUSDT',
#  'COMBOUSDT',
#  'COTIUSDT',
#  'RLCUSDT',
#  'BATUSDT',
#  'TOKENUSDT',
#  'MDTUSDT',
#  'STEEMUSDT',
#  'ZROUSDT',
#  'NKNUSDT',
#  'ARKUSDT',
#  'DGBUSDT',
#  'XLMUSDT',
#  'MEWUSDT',
#  'ONTUSDT',
#  'RVNUSDT',
#  'RSRUSDT',
#  'KASUSDT',
#  'XEMUSDT',
#  'XMRUSDT',
#  'SANDUSDT',
#  'LOOMUSDT',
#  'NEARUSDT',
#  'AUCTIONUSDT',
#  'KAVAUSDT',
#  'OMNIUSDT',
#  'FETUSDT',
#  'CYBERUSDT',
#  'SUIUSDT',
#  'SFPUSDT',
#  'DASHUSDT',
#  'LISTAUSDT',
#  'ARBUSDT',
#  'BCHUSDT',
#  'LINKUSDT',
#  'BALUSDT',
#  'NOTUSDT',
#  'ETHWUSDT',
#  'KLAYUSDT',
#  'TRBUSDT',
#  'LEVERUSDT',
#  'LTCUSDT',
#  'API3USDT',
#  'RNDRUSDT',
#  'HIGHUSDT',
#  'ONEUSDT',
#  'JASMYUSDT',
#  'BONDUSDT',
#  'ENSUSDT',
#  'OCEANUSDT',
#  'DODOXUSDT',
#  'REZUSDT',
#  'BELUSDT',
#  'ETHFIUSDT',
#  'BNTUSDT',
#  'ZRXUSDT',
#  'NMRUSDT',
#  'BTCUSDT_240927',
#  'POLYXUSDT',
#  'ANKRUSDT',
#  'LSKUSDT',
#  'STGUSDT',
#  'C98USDT',
#  'LUNA2USDT',
#  'MAVUSDT',
#  'ZKUSDT',
#  'ILVUSDT',
#  'CRVUSDT',
#  'JTOUSDT',
#  'IOTAUSDT',
#  'THETAUSDT',
#  'SOLUSDT',
#  'SNXUSDT',
#  'HOTUSDT',
#  'ALTUSDT',
#  'AXSUSDT',
#  'CTKUSDT',
#  'FXSUSDT',
#  'PIXELUSDT',
#  'POWRUSDT',
#  'DUSKUSDT',
#  'SKLUSDT',
#  'FLMUSDT',
#  'MASKUSDT',
#  'REEFUSDT',
#  'SSVUSDT',
#  'USTCUSDT',
#  'ONDOUSDT',
#  'GASUSDT',
#  'ORDIUSDT',
#  'BSVUSDT',
#  'ALICEUSDT',
#  'RUNEUSDT',
#  'ASTRUSDT',
#  '1000RATSUSDT',
#  'LQTYUSDT',
#  'MAVIAUSDT',
#  'BEAMXUSDT',
#  'TURBOUSDT',
#  'UNFIUSDT',
#  'HIFIUSDT',
#  'KEYUSDT',
#  'AGIXUSDT',
#  'WOOUSDT',
#  'APEUSDT',
#  'GLMUSDT',
#  'RONINUSDT',
#  'FILUSDT',
#  'ADAUSDT',
#  'BNXUSDT',
#  'BADGERUSDT',
#  'RADUSDT',
#  'HOOKUSDT',
#  '1000FLOKIUSDT',
#  'IDUSDT',
#  'ZILUSDT',
#  'BNBUSDT',
#  'ALPHAUSDT',
#  'SXPUSDT',
#  'DENTUSDT',
#  'FTMUSDT',
#  'XVSUSDT',
#  'STRAXUSDT',
#  'STXUSDT',
#  '1000SHIBUSDT',
#  'MAGICUSDT',
#  'EGLDUSDT',
#  'TNSRUSDT',
#  'VANRYUSDT',
#  'CKBUSDT',
#  'DYDXUSDT',
#  '1000PEPEUSDT',
#  'WLDUSDT',
#  'KNCUSDT',
#  'OPUSDT',
#  'EOSUSDT',
#  'ALGOUSDT',
#  'ZENUSDT',
#  'BTCUSDT',
#  'DARUSDT',
#  'PERPUSDT',
#  'LPTUSDT',
#  'LINAUSDT',
#  'GRTUSDT',
#  'AIUSDT',
#  'PORTALUSDT',
#  'MINAUSDT',
#  'GALAUSDT',
#  'GALUSDT',
#  'RENUSDT',
#  'BICOUSDT',
#  'SPELLUSDT',
#  '1000LUNCUSDT',
#  'ZECUSDT',
#  'SAGAUSDT',
#  'MATICUSDT',
#  'XTZUSDT',
#  'NEOUSDT',
#  'BIGTIMEUSDT',
#  'BLZUSDT',
#  'AGLDUSDT',
#  'DOGEUSDT',
#  'STRKUSDT',
#  'CELRUSDT',
#  'STORJUSDT',
#  'ATOMUSDT',
#  'AMBUSDT',
#  'TWTUSDT',
#  'HBARUSDT']

# %%
def klines(symbol):
    try:
        resp = pd.DataFrame(client.klines(symbol, '1h'))
        resp = resp.iloc[:, :6]
        resp.columns = ['Time','Open','High', 'Low','Close','Volume']
        resp = resp.set_index('Time')
        resp.index = pd.to_datetime(resp.index, unit='ms')
        resp = resp.astype(float)
        return resp
    except ClientError as error:
        print(
            "Found error. status: {}, error code: {}, error message: {}".format(
                error.status_code, error.error_code, error.error_message
            )
        )

def get_price_precision(symbol):
    resp = client.exchange_info()['symbols']
    for elem in resp:
        if elem['symbol'] == symbol:
            print(elem)
            return elem['pricePrecision']

def get_qty_precision(symbol):
    resp = client.exchange_info()['symbols']
    for elem in resp:
        if elem['symbol'] == symbol:
            return elem['quantityPrecision']

# %%
symbol = 'XRPUSDT'
# Out:
#                        Open    High     Low   Close       Volume
# Time
# 2024-06-24 18:00:00  0.4723  0.4736  0.4688  0.4717   26596246.8
# 2024-06-24 19:00:00  0.4717  0.4725  0.4655  0.4668   32390577.6
# 2024-06-24 20:00:00  0.4668  0.4687  0.4610  0.4681   62565441.7
# 2024-06-24 21:00:00  0.4681  0.4734  0.4678  0.4727   27414077.2
# 2024-06-24 22:00:00  0.4728  0.4733  0.4718  0.4720   10184204.9
# ...                     ...     ...     ...     ...          ...
# 2024-07-15 09:00:00  0.5289  0.5341  0.5263  0.5309   63885090.6
# 2024-07-15 10:00:00  0.5309  0.5371  0.5303  0.5356   50460778.4
# 2024-07-15 11:00:00  0.5357  0.5402  0.5290  0.5363  121120853.3
# 2024-07-15 12:00:00  0.5363  0.5365  0.5305  0.5314   66160027.0
# 2024-07-15 13:00:00  0.5313  0.5314  0.5309  0.5310     412026.1
#
# [500 rows x 5 columns]
# {'symbol': 'XRPUSDT', 'pair': 'XRPUSDT', 'contractType': 'PERPETUAL', 'deliveryDate': 4133404800000, 'onboardDate': 1569398400000, 'status': 'TRADING', 'maintMarginPercent': '2.5000', 'requiredMarginPercent': '5.0000', 'baseAsset': 'XRP', 'quoteAsset': 'USDT', 'marginAsset': 'USDT', 'pricePrecision': 4, 'quantityPrecision': 1, 'baseAssetPrecision': 8, 'quotePrecision': 8, 'underlyingType': 'COIN', 'underlyingSubType': ['Payment'], 'settlePlan': 0, 'triggerProtect': '0.0500', 'liquidationFee': '0.012500', 'marketTakeBound': '0.05', 'maxMoveOrderLimit': 10000, 'filters': [{'tickSize': '0.0001', 'maxPrice': '100000', 'filterType': 'PRICE_FILTER', 'minPrice': '0.0143'}, {'minQty': '0.1', 'stepSize': '0.1', 'filterType': 'LOT_SIZE', 'maxQty': '10000000'}, {'stepSize': '0.1', 'maxQty': '2000000', 'filterType': 'MARKET_LOT_SIZE', 'minQty': '0.1'}, {'limit': 200, 'filterType': 'MAX_NUM_ORDERS'}, {'limit': 10, 'filterType': 'MAX_NUM_ALGO_ORDERS'}, {'notional': '5', 'filterType': 'MIN_NOTIONAL'}, {'multiplierDecimal': '4', 'filterType': 'PERCENT_PRICE', 'multiplierUp': '1.0500', 'multiplierDown': '0.9500'}], 'orderTypes': ['LIMIT', 'MARKET', 'STOP', 'STOP_MARKET', 'TAKE_PROFIT', 'TAKE_PROFIT_MARKET', 'TRAILING_STOP_MARKET'], 'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX', 'GTD']}
# 4

# %%
kl = klines(symbol)
ta.trend.macd_diff(kl.Close)
# Out:
# Time
# 2024-06-24 18:00:00         NaN
# 2024-06-24 19:00:00         NaN
# 2024-06-24 20:00:00         NaN
# 2024-06-24 21:00:00         NaN
# 2024-06-24 22:00:00         NaN
#                          ...
# 2024-07-15 09:00:00   -0.000151
# 2024-07-15 10:00:00    0.000235
# 2024-07-15 11:00:00    0.000492
# 2024-07-15 12:00:00    0.000297
# 2024-07-15 13:00:00    0.000115
# Name: MACD_diff_12_26, Length: 500, dtype: float64

# %%
ta.trend.ema_indicator(kl.Close, window=200)
# Out:
# Time
# 2024-06-24 18:00:00         NaN
# 2024-06-24 19:00:00         NaN
# 2024-06-24 20:00:00         NaN
# 2024-06-24 21:00:00         NaN
# 2024-06-24 22:00:00         NaN
#                          ...
# 2024-07-15 09:00:00    0.480593
# 2024-07-15 10:00:00    0.481141
# 2024-07-15 11:00:00    0.481689
# 2024-07-15 12:00:00    0.482184
# 2024-07-15 13:00:00    0.482670
# Name: ema_200, Length: 500, dtype: float64

# %%
client.new_order(symbol='PIXELUSDT', side='BUY', type='STOP_MARKET', quantity=506, timeInForce='GTC', stopPrice=0.1940)
#client.new_order(symbol='PIXELUSDT', side='BUY', type='LIMIT', quantity = 506, timeInForce ='GTC', price=0.1977000)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 client.new_order(symbol='PIXELUSDT', side='BUY', type='STOP_MARKET', quantity=506, timeInForce='GTC', stopPrice=0.1940, price=0.1967000)
#       2 #client.new_order(symbol='PIXELUSDT', side='BUY', type='LIMIT', quantity = 506, timeInForce ='GTC', price=0.1977000)
#
# File ~/venv/lib/python3.12/site-packages/binance/um_futures/account.py:113, in new_order(self, symbol, side, type, **kwargs)
#     111 params = {"symbol": symbol, "side": side, "type": type, **kwargs}
#     112 url_path = "/fapi/v1/order"
# --> 113 return self.sign_request("POST", url_path, params)
#
# File ~/venv/lib/python3.12/site-packages/binance/api.py:83, in API.sign_request(self, http_method, url_path, payload, special)
#      81 query_string = self._prepare_params(payload, special)
#      82 payload["signature"] = self._get_sign(query_string)
# ---> 83 return self.send_request(http_method, url_path, payload, special)
#
# File ~/venv/lib/python3.12/site-packages/binance/api.py:118, in API.send_request(self, http_method, url_path, payload, special)
#     116 response = self._dispatch_request(http_method)(**params)
#     117 logging.debug("raw response from server:" + response.text)
# --> 118 self._handle_exception(response)
#     120 try:
#     121     data = response.json()
#
# File ~/venv/lib/python3.12/site-packages/binance/api.py:172, in API._handle_exception(self, response)
#     170     except JSONDecodeError:
#     171         raise ClientError(status_code, None, response.text, response.headers)
# --> 172     raise ClientError(status_code, err["code"], err["msg"], response.headers)
#     173 raise ServerError(status_code, response.text)
#
# ClientError: (400, -1106, "Parameter 'price' sent when not required.", {'Date': 'Mon, 15 Jul 2024 14:23:43 GMT', 'Content-Type': 'application/json', 'Content-Length': '64', 'Connection': 'keep-alive', 'Server': 'Tengine', 'x-mbx-used-weight-1m': '-1', 'x-mbx-order-count-10s': '1', 'x-mbx-order-count-1m': '4', 'x-response-time': '0ms', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, POST, PUT, DELETE, OPTIONS'})
